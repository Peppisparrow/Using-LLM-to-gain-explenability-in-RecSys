# %%
import pandas as pd
import numpy as np

user_prompts = pd.read_parquet('../../Dataset/ml/ml-latest-small/tuning/user_prompts_PLOTS.parquet')
prompt=user_prompts['prompt'].values[0]
len(prompt)
import re


# 1) cattura (non greedy) i blocchi Title / Description / Genre
pattern = r"""
    Title:\s*(.*?)\s*          # titolo (lazy)
    Description:\s*(.*?)\s*    # descrizione (lazy)
    Genre:\s*(.*?)\s*          # generi    (lazy)
    (?:---|$)                  # fino al separatore o fine stringa
"""
movies = [
    f"Title: {title.strip()}\n"
    f"Description: {desc.rstrip()}\n"
    f"Genre: {genre.strip()}"
    for title, desc, genre in re.findall(pattern, prompt, flags=re.S | re.X)
]
print(len(movies))
# Out:
# 179

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import warnings
warnings.filterwarnings('ignore')

# Carica modello e tokenizer
model_name = "mistralai/Mistral-7B-Instruct-v0.2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True
)

# Input di esempio
input_text = "what is the stronger football player?"
print("=== METODO 1: Generazione normale dal testo ===")
# Tokenizza l'input
inputs = tokenizer(input_text, return_tensors="pt")
input_ids = inputs["input_ids"].to(model.device)
input_length = input_ids.shape[1]

# Genera testo normalmente
with torch.no_grad():
    output_normal = model.generate(
        input_ids,
        max_new_tokens=50,
        temperature=0.1,  # Bassa temperatura per risultati deterministici
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )
# Decodifica solo i nuovi token generati (escludendo l'input)
generated_tokens = output_normal[0][input_length:]
generated_text_normal = tokenizer.decode(generated_tokens, skip_special_tokens=True)
print(f"Input: {input_text}")
print(f"Output: {generated_text_normal}\n")

print("=== METODO 2: Generazione dagli hidden states ===")

# Ottieni gli hidden states dell'input
with torch.no_grad():
    # Forward pass per ottenere gli hidden states
    outputs = model(
        input_ids=input_ids,
        output_hidden_states=True,
        return_dict=True
    )
    
    # Prendi l'ultimo hidden state (output dell'ultimo layer)
    last_hidden_state = outputs.hidden_states[-1]
    
    print(f"Forma hidden states: {last_hidden_state.shape}")
    print(f"Numero di layer: {len(outputs.hidden_states)}")

# Metodo alternativo: usa direttamente inputs_embeds
print("\n=== METODO 2a: Usando inputs_embeds direttamente ===")

# Metodo 1: Media semplice degli embeddings (ogni prompt contribuisce ugualmente)
print("\n--- Metodo 1: Media semplice degli embeddings ---")
input_embeds_list = []
max_length = 0

# Calcola embeddings per ogni movie
for i, movie in enumerate(movies):
    inputs = tokenizer(movie, return_tensors="pt")
    input_ids = inputs["input_ids"].to(model.device)
    
    # Ottieni embeddings
    embeds = model.get_input_embeddings()(input_ids)
    input_embeds_list.append(embeds)
    
    max_length = max(max_length, embeds.shape[1])
    print(f"Movie {i}: '{movie[:30]}...' - Forma embeddings: {embeds.shape}")

# Pad tutti gli embeddings alla stessa lunghezza per poter fare la media
padded_embeds_list = []
mask_list = []
for embeds in input_embeds_list:
    if embeds.shape[1] < max_length:
        # Pad con zeros (o potresti usare il pad_token_id embedding)
        padding = torch.zeros(1, max_length - embeds.shape[1], embeds.shape[2], dtype=embeds.dtype).to(embeds.device)
        padded_embeds = torch.cat([embeds, padding], dim=1)
        # crea una maschera per i token non zero
        mask = torch.ones(1, embeds.shape[1],embeds.shape[2], dtype=torch.bool).to(embeds.device)
        mask = torch.cat([mask, torch.zeros(1, max_length - embeds.shape[1],embeds.shape[2], dtype=torch.bool).to(embeds.device)], dim=1)
    else:
        padded_embeds = embeds
        mask = torch.ones(1, embeds.shape[1],embeds.shape[2], dtype=torch.bool).to(embeds.device)
    padded_embeds_list.append(padded_embeds)
    mask_list.append(mask)

# Calcola la media
stacked_embeds = torch.stack([e.squeeze(0) for e in padded_embeds_list])  # [num_movies, seq_len, hidden_dim]
input_embeds = stacked_embeds.mean(dim=0, keepdim=True)  # [1, seq_len, hidden_dim]

print(f"\nForma embeddings dopo padding: {stacked_embeds.shape}")
print(f"Forma media embeddings: {input_embeds.shape}")


print (f"Forma input embeddings: {input_embeds.shape}")
print(input_embeds)  # Mostra i primi 5 embeddings
with torch.no_grad():
    # Genera usando inputs_embeds invece di input_ids
    output_from_embeds = model.generate(
        inputs_embeds=input_embeds,
        max_new_tokens=50,
        temperature=0.1,
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_embeds = tokenizer.decode(output_from_embeds[0], skip_special_tokens=True)
print(f"Output da embeddings: {generated_text_embeds}")

# Verifica che siano uguali
print("\n=== CONFRONTO RISULTATI ===")
print(f"Testo normale: {generated_text_normal}")
print(f"Testo da embeddings: {generated_text_embeds}")
print(f"I risultati sono identici: {generated_text_normal == generated_text_embeds}")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# === METODO 1: Generazione normale dal testo ===
# Input: what is the stronger football player?
# Output:
#
# The term "stronger football player" can be interpreted in different ways, depending on the context. Here are a few possible interpretations and some factors that could influence the answer:
#
# 1. Physical strength: In terms of raw muscle
#
# === METODO 2: Generazione dagli hidden states ===
# Forma hidden states: torch.Size([1, 8, 4096])
# Numero di layer: 33
#
# === METODO 2a: Usando inputs_embeds direttamente ===
#
# --- Metodo 1: Media semplice degli embeddings ---
# Movie 0: 'Title: McHale's Navy
# Descripti...' - Forma embeddings: torch.Size([1, 1192, 4096])
# Movie 1: 'Title: Rush Hour
# Description: ...' - Forma embeddings: torch.Size([1, 1173, 4096])
# Movie 2: 'Title: Back to the Future Part...' - Forma embeddings: torch.Size([1, 1076, 4096])
# Movie 3: 'Title: Dracula
# Description: Re...' - Forma embeddings: torch.Size([1, 1199, 4096])
# Movie 4: 'Title: So I Married an Axe Mur...' - Forma embeddings: torch.Size([1, 828, 4096])
# Movie 5: 'Title: Willy Wonka & the Choco...' - Forma embeddings: torch.Size([1, 975, 4096])
# Movie 6: 'Title: Goonies, The
# Descriptio...' - Forma embeddings: torch.Size([1, 748, 4096])
# Movie 7: 'Title: Canadian Bacon
# Descript...' - Forma embeddings: torch.Size([1, 1006, 4096])
# Movie 8: 'Title: James and the Giant Pea...' - Forma embeddings: torch.Size([1, 814, 4096])
# Movie 9: 'Title: Apocalypse Now
# Descript...' - Forma embeddings: torch.Size([1, 901, 4096])
# Movie 10: 'Title: Fantasia
# Description: I...' - Forma embeddings: torch.Size([1, 456, 4096])
# Movie 11: 'Title: Go
# Description: Around ...' - Forma embeddings: torch.Size([1, 1213, 4096])
# Movie 12: 'Title: Blazing Saddles
# Descrip...' - Forma embeddings: torch.Size([1, 809, 4096])
# Movie 13: 'Title: Honey, I Shrunk the Kid...' - Forma embeddings: torch.Size([1, 1399, 4096])
# Movie 14: 'Title: Tommy Boy
# Description: ...' - Forma embeddings: torch.Size([1, 1204, 4096])
# Movie 15: 'Title: Road Trip
# Description: ...' - Forma embeddings: torch.Size([1, 1365, 4096])
# Movie 16: 'Title: American Beauty
# Descrip...' - Forma embeddings: torch.Size([1, 882, 4096])
# Movie 17: 'Title: Star Wars: Episode IV -...' - Forma embeddings: torch.Size([1, 101, 4096])
# Movie 18: 'Title: Dick Tracy
# Description:...' - Forma embeddings: torch.Size([1, 1038, 4096])
# Movie 19: 'Title: Independence Day (a.k.a...' - Forma embeddings: torch.Size([1, 120, 4096])
# Movie 20: 'Title: Secret of NIMH, The
# Des...' - Forma embeddings: torch.Size([1, 84, 4096])
# Movie 21: 'Title: Tombstone
# Description: ...' - Forma embeddings: torch.Size([1, 927, 4096])
# Movie 22: 'Title: Silence of the Lambs, T...' - Forma embeddings: torch.Size([1, 123, 4096])
# Movie 23: 'Title: Swingers
# Description: M...' - Forma embeddings: torch.Size([1, 389, 4096])
# Movie 24: 'Title: Bottle Rocket
# Descripti...' - Forma embeddings: torch.Size([1, 1030, 4096])
# Movie 25: 'Title: Platoon
# Description: In...' - Forma embeddings: torch.Size([1, 970, 4096])
# Movie 26: 'Title: Teenage Mutant Ninja Tu...' - Forma embeddings: torch.Size([1, 1804, 4096])
# Movie 27: 'Title: Star Wars: Episode V - ...' - Forma embeddings: torch.Size([1, 127, 4096])
# Movie 28: 'Title: 13th Warrior, The
# Descr...' - Forma embeddings: torch.Size([1, 82, 4096])
# Movie 29: 'Title: Tron
# Description: Kevin...' - Forma embeddings: torch.Size([1, 994, 4096])
# Movie 30: 'Title: Mission: Impossible
# Des...' - Forma embeddings: torch.Size([1, 890, 4096])
# Movie 31: 'Title: Talented Mr. Ripley, Th...' - Forma embeddings: torch.Size([1, 127, 4096])
# Movie 32: 'Title: Heat
# Description: Neil ...' - Forma embeddings: torch.Size([1, 1022, 4096])
# Movie 33: 'Title: Young Sherlock Holmes
# D...' - Forma embeddings: torch.Size([1, 1251, 4096])
# Movie 34: 'Title: Sword in the Stone, The...' - Forma embeddings: torch.Size([1, 115, 4096])
# Movie 35: 'Title: Monty Python's Life of ...' - Forma embeddings: torch.Size([1, 926, 4096])
# Movie 36: 'Title: Man with the Golden Gun...' - Forma embeddings: torch.Size([1, 136, 4096])
# Movie 37: 'Title: Abyss, The
# Description:...' - Forma embeddings: torch.Size([1, 98, 4096])
# Movie 38: 'Title: Batman
# Description: As ...' - Forma embeddings: torch.Size([1, 1065, 4096])
# Movie 39: 'Title: Princess Bride, The
# Des...' - Forma embeddings: torch.Size([1, 99, 4096])
# Movie 40: 'Title: Return to Oz
# Descriptio...' - Forma embeddings: torch.Size([1, 1170, 4096])
# Movie 41: 'Title: Rock, The
# Description: ...' - Forma embeddings: torch.Size([1, 88, 4096])
# Movie 42: 'Title: Mad Max
# Description: "A...' - Forma embeddings: torch.Size([1, 934, 4096])
# Movie 43: 'Title: Good Morning, Vietnam
# D...' - Forma embeddings: torch.Size([1, 964, 4096])
# Movie 44: 'Title: Duck Soup
# Description: ...' - Forma embeddings: torch.Size([1, 521, 4096])
# Movie 45: 'Title: Howard the Duck
# Descrip...' - Forma embeddings: torch.Size([1, 769, 4096])
# Movie 46: 'Title: Bambi
# Description: A do...' - Forma embeddings: torch.Size([1, 694, 4096])
# Movie 47: 'Title: Indiana Jones and the L...' - Forma embeddings: torch.Size([1, 1303, 4096])
# Movie 48: 'Title: Groundhog Day
# Descripti...' - Forma embeddings: torch.Size([1, 613, 4096])
# Movie 49: 'Title: Ghost and Mrs. Muir, Th...' - Forma embeddings: torch.Size([1, 51, 4096])
# Movie 50: 'Title: Logan's Run
# Description...' - Forma embeddings: torch.Size([1, 998, 4096])
# Movie 51: 'Title: Seven (a.k.a. Se7en)
# De...' - Forma embeddings: torch.Size([1, 122, 4096])
# Movie 52: 'Title: Transformers: The Movie...' - Forma embeddings: torch.Size([1, 75, 4096])
# Movie 53: 'Title: Toy Story
# Description: ...' - Forma embeddings: torch.Size([1, 905, 4096])
# Movie 54: 'Title: Star Wars: Episode I - ...' - Forma embeddings: torch.Size([1, 75, 4096])
# Movie 55: 'Title: Rushmore
# Description: M...' - Forma embeddings: torch.Size([1, 850, 4096])
# Movie 56: 'Title: Full Metal Jacket
# Descr...' - Forma embeddings: torch.Size([1, 1110, 4096])
# Movie 57: 'Title: Spaceballs
# Description:...' - Forma embeddings: torch.Size([1, 981, 4096])
# Movie 58: 'Title: Iron Giant, The
# Descrip...' - Forma embeddings: torch.Size([1, 80, 4096])
# Movie 59: 'Title: Citizen Kane
# Descriptio...' - Forma embeddings: torch.Size([1, 892, 4096])
# Movie 60: 'Title: ¡Three Amigos!
# Descript...' - Forma embeddings: torch.Size([1, 1027, 4096])
# Movie 61: 'Title: Forrest Gump
# Descriptio...' - Forma embeddings: torch.Size([1, 928, 4096])
# Movie 62: 'Title: Game, The
# Description: ...' - Forma embeddings: torch.Size([1, 107, 4096])
# Movie 63: 'Title: Sleeping Beauty
# Descrip...' - Forma embeddings: torch.Size([1, 1227, 4096])
# Movie 64: 'Title: Frankenstein
# Descriptio...' - Forma embeddings: torch.Size([1, 1144, 4096])
# Movie 65: 'Title: Winnie the Pooh and the...' - Forma embeddings: torch.Size([1, 793, 4096])
# Movie 66: 'Title: RoboCop
# Description: In...' - Forma embeddings: torch.Size([1, 1006, 4096])
# Movie 67: 'Title: Toys
# Description: Kenne...' - Forma embeddings: torch.Size([1, 850, 4096])
# Movie 68: 'Title: Henry V
# Description: Th...' - Forma embeddings: torch.Size([1, 1415, 4096])
# Movie 69: 'Title: Lord of the Rings, The
# ...' - Forma embeddings: torch.Size([1, 57, 4096])
# Movie 70: 'Title: Alice in Wonderland
# Des...' - Forma embeddings: torch.Size([1, 1050, 4096])
# Movie 71: 'Title: American Tail, An
# Descr...' - Forma embeddings: torch.Size([1, 104, 4096])
# Movie 72: 'Title: Song of the South
# Descr...' - Forma embeddings: torch.Size([1, 1020, 4096])
# Movie 73: 'Title: She's the One
# Descripti...' - Forma embeddings: torch.Size([1, 1038, 4096])
# Movie 74: 'Title: Shining, The
# Descriptio...' - Forma embeddings: torch.Size([1, 74, 4096])
# Movie 75: 'Title: Fugitive, The
# Descripti...' - Forma embeddings: torch.Size([1, 54, 4096])
# Movie 76: 'Title: Fargo
# Description: In t...' - Forma embeddings: torch.Size([1, 995, 4096])
# Movie 77: 'Title: Jurassic Park
# Descripti...' - Forma embeddings: torch.Size([1, 1112, 4096])
# Movie 78: 'Title: Lock, Stock & Two Smoki...' - Forma embeddings: torch.Size([1, 86, 4096])
# Movie 79: 'Title: Goldfinger
# Description:...' - Forma embeddings: torch.Size([1, 1261, 4096])
# Movie 80: 'Title: M*A*S*H (a.k.a. MASH)
# D...' - Forma embeddings: torch.Size([1, 61, 4096])
# Movie 81: 'Title: Grumpier Old Men
# Descri...' - Forma embeddings: torch.Size([1, 544, 4096])
# Movie 82: 'Title: Charlotte's Web
# Descrip...' - Forma embeddings: torch.Size([1, 994, 4096])
# Movie 83: 'Title: Billy Madison
# Descripti...' - Forma embeddings: torch.Size([1, 671, 4096])
# Movie 84: 'Title: Back to the Future
# Desc...' - Forma embeddings: torch.Size([1, 779, 4096])
# Movie 85: 'Title: That Thing You Do!
# Desc...' - Forma embeddings: torch.Size([1, 906, 4096])
# Movie 86: 'Title: Teenage Mutant Ninja Tu...' - Forma embeddings: torch.Size([1, 1182, 4096])
# Movie 87: 'Title: Usual Suspects, The
# Des...' - Forma embeddings: torch.Size([1, 122, 4096])
# Movie 88: 'Title: Escape to Witch Mountai...' - Forma embeddings: torch.Size([1, 753, 4096])
# Movie 89: 'Title: Nosferatu (Nosferatu, e...' - Forma embeddings: torch.Size([1, 124, 4096])
# Movie 90: 'Title: Ed Wood
# Description: In...' - Forma embeddings: torch.Size([1, 849, 4096])
# Movie 91: 'Title: Big Lebowski, The
# Descr...' - Forma embeddings: torch.Size([1, 96, 4096])
# Movie 92: 'Title: I Still Know What You D...' - Forma embeddings: torch.Size([1, 1376, 4096])
# Movie 93: 'Title: Thunderball
# Description...' - Forma embeddings: torch.Size([1, 1270, 4096])
# Movie 94: 'Title: Twister
# Description: On...' - Forma embeddings: torch.Size([1, 1865, 4096])
# Movie 95: 'Title: Psycho
# Description: Dur...' - Forma embeddings: torch.Size([1, 1058, 4096])
# Movie 96: 'Title: From Dusk Till Dawn
# Des...' - Forma embeddings: torch.Size([1, 637, 4096])
# Movie 97: 'Title: Flight of the Navigator...' - Forma embeddings: torch.Size([1, 957, 4096])
# Movie 98: 'Title: Face/Off
# Description: F...' - Forma embeddings: torch.Size([1, 1078, 4096])
# Movie 99: 'Title: Wizard of Oz, The
# Descr...' - Forma embeddings: torch.Size([1, 98, 4096])
# Movie 100: 'Title: Batman Returns
# Descript...' - Forma embeddings: torch.Size([1, 1047, 4096])
# Movie 101: 'Title: Labyrinth
# Description: ...' - Forma embeddings: torch.Size([1, 1049, 4096])
# Movie 102: 'Title: Scream 3
# Description: C...' - Forma embeddings: torch.Size([1, 1111, 4096])
# Movie 103: 'Title: Willow
# Description: Whe...' - Forma embeddings: torch.Size([1, 1450, 4096])
# Movie 104: 'Title: Black Cauldron, The
# Des...' - Forma embeddings: torch.Size([1, 1198, 4096])
# Movie 105: 'Title: Rocky Horror Picture Sh...' - Forma embeddings: torch.Size([1, 85, 4096])
# Movie 106: 'Title: Romancing the Stone
# Des...' - Forma embeddings: torch.Size([1, 909, 4096])
# Movie 107: 'Title: Mummy, The
# Description:...' - Forma embeddings: torch.Size([1, 127, 4096])
# Movie 108: 'Title: Excalibur
# Description: ...' - Forma embeddings: torch.Size([1, 1780, 4096])
# Movie 109: 'Title: Superman II
# Description...' - Forma embeddings: torch.Size([1, 949, 4096])
# Movie 110: 'Title: Legend
# Description: In ...' - Forma embeddings: torch.Size([1, 879, 4096])
# Movie 111: 'Title: Few Good Men, A
# Descrip...' - Forma embeddings: torch.Size([1, 91, 4096])
# Movie 112: 'Title: Road Warrior, The (Mad ...' - Forma embeddings: torch.Size([1, 125, 4096])
# Movie 113: 'Title: X-Men
# Description: In 1...' - Forma embeddings: torch.Size([1, 1105, 4096])
# Movie 114: 'Title: Messenger: The Story of...' - Forma embeddings: torch.Size([1, 103, 4096])
# Movie 115: 'Title: Monty Python and the Ho...' - Forma embeddings: torch.Size([1, 755, 4096])
# Movie 116: 'Title: SLC Punk!
# Description: ...' - Forma embeddings: torch.Size([1, 1080, 4096])
# Movie 117: 'Title: Stargate
# Description: E...' - Forma embeddings: torch.Size([1, 1141, 4096])
# Movie 118: 'Title: Alien
# Description: The ...' - Forma embeddings: torch.Size([1, 1041, 4096])
# Movie 119: 'Title: Rescuers, The
# Descripti...' - Forma embeddings: torch.Size([1, 57, 4096])
# Movie 120: 'Title: Three Musketeers, The
# D...' - Forma embeddings: torch.Size([1, 138, 4096])
# Movie 121: 'Title: Beetlejuice
# Description...' - Forma embeddings: torch.Size([1, 893, 4096])
# Movie 122: 'Title: Pulp Fiction
# Descriptio...' - Forma embeddings: torch.Size([1, 894, 4096])
# Movie 123: 'Title: Adventures of Robin Hoo...' - Forma embeddings: torch.Size([1, 57, 4096])
# Movie 124: 'Title: Mrs. Doubtfire
# Descript...' - Forma embeddings: torch.Size([1, 1074, 4096])
# Movie 125: 'Title: Con Air
# Description: Ho...' - Forma embeddings: torch.Size([1, 1173, 4096])
# Movie 126: 'Title: From Russia with Love
# D...' - Forma embeddings: torch.Size([1, 1645, 4096])
# Movie 127: 'Title: Sister Act
# Description:...' - Forma embeddings: torch.Size([1, 910, 4096])
# Movie 128: 'Title: Mask, The
# Description: ...' - Forma embeddings: torch.Size([1, 132, 4096])
# Movie 129: 'Title: Quiet Man, The
# Descript...' - Forma embeddings: torch.Size([1, 40, 4096])
# Movie 130: 'Title: Dances with Wolves
# Desc...' - Forma embeddings: torch.Size([1, 1159, 4096])
# Movie 131: 'Title: Crocodile Dundee
# Descri...' - Forma embeddings: torch.Size([1, 747, 4096])
# Movie 132: 'Title: Office Space
# Descriptio...' - Forma embeddings: torch.Size([1, 892, 4096])
# Movie 133: 'Title: Predator
# Description: A...' - Forma embeddings: torch.Size([1, 809, 4096])
# Movie 134: 'Title: Being John Malkovich
# De...' - Forma embeddings: torch.Size([1, 1167, 4096])
# Movie 135: 'Title: Clerks
# Description: Dan...' - Forma embeddings: torch.Size([1, 1125, 4096])
# Movie 136: 'Title: Mr. Smith Goes to Washi...' - Forma embeddings: torch.Size([1, 984, 4096])
# Movie 137: 'Title: Reservoir Dogs
# Descript...' - Forma embeddings: torch.Size([1, 660, 4096])
# Movie 138: 'Title: Blues Brothers, The
# Des...' - Forma embeddings: torch.Size([1, 50, 4096])
# Movie 139: 'Title: Green Mile, The
# Descrip...' - Forma embeddings: torch.Size([1, 92, 4096])
# Movie 140: 'Title: Hook
# Description: Peter...' - Forma embeddings: torch.Size([1, 956, 4096])
# Movie 141: 'Title: Red Dawn
# Description: T...' - Forma embeddings: torch.Size([1, 1056, 4096])
# Movie 142: 'Title: Wedding Singer, The
# Des...' - Forma embeddings: torch.Size([1, 83, 4096])
# Movie 143: 'Title: Shaft
# Description: John...' - Forma embeddings: torch.Size([1, 897, 4096])
# Movie 144: 'Title: Dr. No
# Description: Joh...' - Forma embeddings: torch.Size([1, 959, 4096])
# Movie 145: 'Title: Newton Boys, The
# Descri...' - Forma embeddings: torch.Size([1, 91, 4096])
# Movie 146: 'Title: Desperado
# Description: ...' - Forma embeddings: torch.Size([1, 996, 4096])
# Movie 147: 'Title: Grumpy Old Men
# Descript...' - Forma embeddings: torch.Size([1, 970, 4096])
# Movie 148: 'Title: Clockwork Orange, A
# Des...' - Forma embeddings: torch.Size([1, 130, 4096])
# Movie 149: 'Title: Bedknobs and Broomstick...' - Forma embeddings: torch.Size([1, 1007, 4096])
# Movie 150: 'Title: Fight Club
# Description:...' - Forma embeddings: torch.Size([1, 983, 4096])
# Movie 151: 'Title: Basic Instinct
# Descript...' - Forma embeddings: torch.Size([1, 797, 4096])
# Movie 152: 'Title: Best Men
# Description: J...' - Forma embeddings: torch.Size([1, 124, 4096])
# Movie 153: 'Title: Pete's Dragon
# Descripti...' - Forma embeddings: torch.Size([1, 1382, 4096])
# Movie 154: 'Title: King Kong
# Description: ...' - Forma embeddings: torch.Size([1, 820, 4096])
# Movie 155: 'Title: Terminator, The
# Descrip...' - Forma embeddings: torch.Size([1, 126, 4096])
# Movie 156: 'Title: Braveheart
# Description:...' - Forma embeddings: torch.Size([1, 924, 4096])
# Movie 157: 'Title: Rocketeer, The
# Descript...' - Forma embeddings: torch.Size([1, 59, 4096])
# Movie 158: 'Title: Goodfellas
# Description:...' - Forma embeddings: torch.Size([1, 960, 4096])
# Movie 159: 'Title: Easy Rider
# Description:...' - Forma embeddings: torch.Size([1, 775, 4096])
# Movie 160: 'Title: Psycho
# Description: Mar...' - Forma embeddings: torch.Size([1, 1178, 4096])
# Movie 161: 'Title: L.A. Confidential
# Descr...' - Forma embeddings: torch.Size([1, 1088, 4096])
# Movie 162: 'Title: Ghostbusters (a.k.a. Gh...' - Forma embeddings: torch.Size([1, 130, 4096])
# Movie 163: 'Title: Matrix, The
# Description...' - Forma embeddings: torch.Size([1, 64, 4096])
# Movie 164: 'Title: Edward Scissorhands
# Des...' - Forma embeddings: torch.Size([1, 918, 4096])
# Movie 165: 'Title: Highlander
# Description:...' - Forma embeddings: torch.Size([1, 993, 4096])
# Movie 166: 'Title: Space Jam
# Description: ...' - Forma embeddings: torch.Size([1, 1040, 4096])
# Movie 167: 'Title: Ladyhawke
# Description: ...' - Forma embeddings: torch.Size([1, 1018, 4096])
# Movie 168: 'Title: Who Framed Roger Rabbit...' - Forma embeddings: torch.Size([1, 96, 4096])
# Movie 169: 'Title: Wayne's World
# Descripti...' - Forma embeddings: torch.Size([1, 657, 4096])
# Movie 170: 'Title: Negotiator, The
# Descrip...' - Forma embeddings: torch.Size([1, 114, 4096])
# Movie 171: 'Title: Schindler's List
# Descri...' - Forma embeddings: torch.Size([1, 962, 4096])
# Movie 172: 'Title: Encino Man
# Description:...' - Forma embeddings: torch.Size([1, 913, 4096])
# Movie 173: 'Title: Longest Day, The
# Descri...' - Forma embeddings: torch.Size([1, 115, 4096])
# Movie 174: 'Title: Total Recall
# Descriptio...' - Forma embeddings: torch.Size([1, 1009, 4096])
# Movie 175: 'Title: Small Soldiers
# Descript...' - Forma embeddings: torch.Size([1, 1246, 4096])
# Movie 176: 'Title: Dogma
# Description: Bart...' - Forma embeddings: torch.Size([1, 997, 4096])
# Movie 177: 'Title: Kiss the Girls
# Descript...' - Forma embeddings: torch.Size([1, 732, 4096])
# Movie 178: 'Title: JFK
# Description: The fi...' - Forma embeddings: torch.Size([1, 1062, 4096])
#
# Forma embeddings dopo padding: torch.Size([179, 1865, 4096])
# Forma media embeddings: torch.Size([1, 1865, 4096])
# Forma input embeddings: torch.Size([1, 1865, 4096])
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# tensor([[[-4.3640e-03, -1.0633e-04, -5.6152e-03,  ..., -5.0545e-05,
#           -1.1520e-03,  1.5926e-04],
#          [-6.4850e-04,  6.1340e-03,  1.0757e-03,  ..., -8.8882e-04,
#           -3.4027e-03, -1.6403e-03],
#          [-9.8419e-04, -9.7275e-04,  4.5300e-05,  ..., -8.3923e-04,
#           -2.1100e-05, -1.4114e-03],
#          ...,
#          [-8.4639e-06,  2.2829e-05,  1.0073e-05,  ..., -1.6689e-06,
#            3.5286e-05,  3.9339e-06],
#          [-3.8743e-06, -8.5235e-06,  4.0531e-06,  ...,  2.8610e-06,
#           -7.5102e-06,  1.8895e-05],
#          [ 1.7881e-05,  1.2219e-05, -1.1742e-05,  ...,  3.5763e-06,
#           -3.8147e-06, -1.0371e-05]]], device='cuda:0', dtype=torch.float16,
#        grad_fn=<MeanBackward1>)
# Output da embeddings: {}�����€€™s �€™s �€™s �€™s �€™s �€™s �€™s �€™s �€™s
#
# === CONFRONTO RISULTATI ===
# Testo normale:
#
# The term "stronger football player" can be interpreted in different ways, depending on the context. Here are a few possible interpretations and some factors that could influence the answer:
#
# 1. Physical strength: In terms of raw muscle
# Testo da embeddings: {}�����€€™s �€™s �€™s �€™s �€™s �€™s �€™s �€™s �€™s
# I risultati sono identici: False

# %%
# Metodo 2: Media ponderata basata sulla lunghezza
print("\n--- Metodo 2: Media ponderata (peso basato su lunghezza) ---")
weighted_sum = torch.zeros_like(padded_embeds_list[0])
total_weight = 0

for embeds, original_embeds in zip(padded_embeds_list, input_embeds_list):
    weight = original_embeds.shape[1]  # Peso = lunghezza originale
    weighted_sum += embeds * weight
    total_weight += weight

weighted_mean_embeds = weighted_sum / total_weight

with torch.no_grad():
    output_weighted = model.generate(
        inputs_embeds=weighted_mean_embeds,
        max_new_tokens=50,
        temperature=0.1,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_weighted = tokenizer.decode(output_weighted[0], skip_special_tokens=True)
print(f"Output da media ponderata: {generated_text_weighted}")

# Metodo 3: Media solo dei primi N token di ogni prompt
print("\n--- Metodo 3: Media dei primi N token ---")
n_tokens = 100  # Prendi solo i primi 5 token di ogni prompt

truncated_embeds_list = []
for i, movie in enumerate(movies):
    inputs = tokenizer(movie, return_tensors="pt", max_length=n_tokens, truncation=True)
    input_ids = inputs["input_ids"].to(model.device)
    embeds = model.get_input_embeddings()(input_ids)
    
    # Assicurati che abbiano tutti esattamente n_tokens
    if embeds.shape[1] < n_tokens:
        padding = torch.zeros(1, n_tokens - embeds.shape[1], embeds.shape[2], dtype=embeds.dtype).to(embeds.device)
        embeds = torch.cat([embeds, padding], dim=1)
    
    truncated_embeds_list.append(embeds)

# Stack e media
stacked_truncated = torch.stack([e.squeeze(0) for e in truncated_embeds_list])
mean_truncated = stacked_truncated.mean(dim=0, keepdim=True)

with torch.no_grad():
    output_truncated = model.generate(
        inputs_embeds=mean_truncated,
        max_new_tokens=50,
        temperature=0.7,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_truncated = tokenizer.decode(output_truncated[0], skip_special_tokens=True)
print(f"Output da media dei primi {n_tokens} token: {generated_text_truncated}")
# Out:
# --- Metodo 2: Media ponderata (peso basato su lunghezza) ---
# Output da media ponderata: {}����€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€€
#
# --- Metodo 3: Media dei primi N token ---
# Output da media dei primi 100 token: rock band
#
# Date: 2023-03-21 14:13:08
# ---
#
# **Title:** *The Epic Saga of "Misspelled Words" Rock Band:

# %%
print("\n--- Metodo 4: Media escludendo componenti zero (padding-aware) ---")

# Crea maschere per identificare le posizioni con padding (tutti zeri)
masks_list = []
for embeds, original_embeds in zip(padded_embeds_list, input_embeds_list):
    # Crea una maschera: 1 per posizioni valide, 0 per padding
    mask = torch.ones_like(embeds)
    if embeds.shape[1] > original_embeds.shape[1]:
        # Le posizioni dopo la lunghezza originale sono padding
        mask[:, original_embeds.shape[1]:, :] = 0
    masks_list.append(mask)

# Stack embeddings e maschere
stacked_embeds = torch.stack([e.squeeze(0) for e in padded_embeds_list])  # [num_movies, seq_len, hidden_dim]
stacked_masks = torch.stack([m.squeeze(0) for m in masks_list])  # [num_movies, seq_len, hidden_dim]

# Calcola la somma pesata e il conteggio per ogni componente
weighted_sum_nonzero = (stacked_embeds * stacked_masks).sum(dim=0)  # [seq_len, hidden_dim]
count_nonzero = stacked_masks.sum(dim=0)  # [seq_len, hidden_dim]

# Evita divisione per zero
count_nonzero = torch.clamp(count_nonzero, min=1e-9)

# Media considerando solo componenti non-zero
mean_nonzero = weighted_sum_nonzero / count_nonzero
mean_nonzero_embeds = mean_nonzero.unsqueeze(0)  # [1, seq_len, hidden_dim]

# Per debug: mostra quante componenti sono state mediate per alcune posizioni
print(f"Esempio conteggi non-zero per posizione 0: min={count_nonzero[0].min():.0f}, max={count_nonzero[0].max():.0f}")
print(f"Esempio conteggi non-zero per ultima posizione: min={count_nonzero[-1].min():.0f}, max={count_nonzero[-1].max():.0f}")

with torch.no_grad():
    output_nonzero = model.generate(
        inputs_embeds=mean_nonzero_embeds,
        max_new_tokens=50,
        temperature=0.1,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_nonzero = tokenizer.decode(output_nonzero[0], skip_special_tokens=True)
print(f"Output da media non-zero: {generated_text_nonzero}")
# Out:
# --- Metodo 4: Media escludendo componenti zero (padding-aware) ---
# Esempio conteggi non-zero per posizione 0: min=179, max=179
# Esempio conteggi non-zero per ultima posizione: min=1, max=1
# Output da media non-zero:
#
# Title: The Day After Tomorrow
# Description: In this disaster film, climate scientist Jack Hall (Dennis Quaid) predicts a new Ice Age that will result from the climate shifting rapidly into a super-cold state, causing

# %%
for movie in movies:
    print(f"Movie: {movie}")  # Mostra solo i primi 30 caratteri per brevità
# Out:
# Movie: Title: McHale's Navy
to pull the United States out of the Vietnam War and dismantle the CIA. X encourages Garrison to keep digging and prosecute New Orleans-based international businessman Clay Shaw for his alleged involvement. When Shaw is interrogated, the businessman denies any knowledge of meeting Ferrie, O'Keefe or Oswald, but he is soon charged with conspiring to murder the President. Some of Garrison's staff begin to doubt his motives and disagree with his methods, and leave the investigation. Garrison's marriage is strained when his wife Liz (Sissy Spacek) complains that he is spending more time on the case than with his own family. After a sinister phone call is made to their daughter, Liz accuses Garrison of being selfish and attacking Shaw only because of his homosexuality. In addition, the media launches attacks on television and in newspapers attacking Garrison's character and criticizing the way his office is spending taxpayers' money. Some key witnesses become scared and refuse to testify while others, such as Ferrie, are killed in suspicious circumstances. Before his death, Ferrie tells Garrison that he believes people are after him, and reveals there was a conspiracy around Kennedy's death. The trial of Clay Shaw takes place in 1969. Garrison presents the court with further evidence of multiple killers and dismissing the single bullet theory, and proposes a Dealey Plaza shots scenario involving three assassins who fired six total shots and framing Oswald for the murders of Kennedy and officer J. D. Ti ...
# Genre: Drama|Mystery|Thriller

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import warnings
warnings.filterwarnings('ignore')

# Carica modello e tokenizer
model_name = "mistralai/Mistral-7B-Instruct-v0.2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True
)
print("\n=== METODO 2a: Usando inputs_embeds direttamente ===")

# Metodo 1: Media semplice degli embeddings (ogni prompt contribuisce ugualmente)
print("\n--- Metodo 1: Media semplice degli embeddings ---")
input_embeds_list = []
max_length = 0

# Calcola embeddings per ogni movie
for i, movie in enumerate(movies):
    inputs = tokenizer(movie, return_tensors="pt")
    input_ids = inputs["input_ids"].to(model.device)
    
    # Ottieni embeddings
    embeds = model.get_input_embeddings()(input_ids)
    input_embeds_list.append(embeds)
    
    max_length = max(max_length, embeds.shape[1])

# Pad tutti gli embeddings alla stessa lunghezza per poter fare la media
padded_embeds_list = []
mask_list = []
for embeds in input_embeds_list:
    if embeds.shape[1] < max_length:
        # Pad con zeros (o potresti usare il pad_token_id embedding)
        padding = torch.zeros(1, max_length - embeds.shape[1], embeds.shape[2], dtype=embeds.dtype).to(embeds.device)
        padded_embeds = torch.cat([embeds, padding], dim=1)
        # crea una maschera per i token non zero
        mask = torch.ones(1, embeds.shape[1],embeds.shape[2], dtype=torch.bool).to(embeds.device)
        mask = torch.cat([mask, torch.zeros(1, max_length - embeds.shape[1],embeds.shape[2], dtype=torch.bool).to(embeds.device)], dim=1)
    else:
        padded_embeds = embeds
        mask = torch.ones(1, embeds.shape[1],embeds.shape[2], dtype=torch.bool).to(embeds.device)
    padded_embeds_list.append(padded_embeds)
    mask_list.append(mask)

# Calcola la media
stacked_embeds = torch.stack([e.squeeze(0) for e in padded_embeds_list])  # [num_movies, seq_len, hidden_dim]
input_embeds = stacked_embeds.mean(dim=0, keepdim=True)  # [1, seq_len, hidden_dim]

print(input_embeds)  # Mostra i primi 5 embeddings
with torch.no_grad():
    # Genera usando inputs_embeds invece di input_ids
    output_from_embeds = model.generate(
        inputs_embeds=input_embeds,
        max_new_tokens=10,
        temperature=0.1,
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_embeds = tokenizer.decode(output_from_embeds[0], skip_special_tokens=True)
print(f"Output da embeddings: {generated_text_embeds}")

# Metodo 2: Media ponderata basata sulla lunghezza
print("\n--- Metodo 2: Media ponderata (peso basato su lunghezza) ---")
weighted_sum = torch.zeros_like(padded_embeds_list[0])
total_weight = 0

for embeds, original_embeds in zip(padded_embeds_list, input_embeds_list):
    weight = original_embeds.shape[1]  # Peso = lunghezza originale
    weighted_sum += embeds * weight
    total_weight += weight

weighted_mean_embeds = weighted_sum / total_weight

with torch.no_grad():
    output_weighted = model.generate(
        inputs_embeds=weighted_mean_embeds,
        max_new_tokens=10,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_weighted = tokenizer.decode(output_weighted[0], skip_special_tokens=True)
print(f"Output da media ponderata: {generated_text_weighted}")

# Metodo 3: Media solo dei primi N token di ogni prompt
print("\n--- Metodo 3: Media dei primi N token ---")
n_tokens = 100  # Prendi solo i primi 5 token di ogni prompt

truncated_embeds_list = []
for i, movie in enumerate(movies):
    inputs = tokenizer(movie, return_tensors="pt", max_length=n_tokens, truncation=True)
    input_ids = inputs["input_ids"].to(model.device)
    embeds = model.get_input_embeddings()(input_ids)
    
    # Assicurati che abbiano tutti esattamente n_tokens
    if embeds.shape[1] < n_tokens:
        padding = torch.zeros(1, n_tokens - embeds.shape[1], embeds.shape[2], dtype=embeds.dtype).to(embeds.device)
        embeds = torch.cat([embeds, padding], dim=1)
    
    truncated_embeds_list.append(embeds)

# Stack e media
stacked_truncated = torch.stack([e.squeeze(0) for e in truncated_embeds_list])
mean_truncated = stacked_truncated.mean(dim=0, keepdim=True)

with torch.no_grad():
    output_truncated = model.generate(
        inputs_embeds=mean_truncated,
        max_new_tokens=100,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_truncated = tokenizer.decode(output_truncated[0], skip_special_tokens=True)
print(f"Output da media dei primi {n_tokens} token: {generated_text_truncated}")

print("\n--- Metodo 4: Media escludendo componenti zero (padding-aware) ---")

# Crea maschere per identificare le posizioni con padding (tutti zeri)
masks_list = []
for embeds, original_embeds in zip(padded_embeds_list, input_embeds_list):
    # Crea una maschera: 1 per posizioni valide, 0 per padding
    mask = torch.ones_like(embeds)
    if embeds.shape[1] > original_embeds.shape[1]:
        # Le posizioni dopo la lunghezza originale sono padding
        mask[:, original_embeds.shape[1]:, :] = 0
    masks_list.append(mask)

# Stack embeddings e maschere
stacked_embeds = torch.stack([e.squeeze(0) for e in padded_embeds_list])  # [num_movies, seq_len, hidden_dim]
stacked_masks = torch.stack([m.squeeze(0) for m in masks_list])  # [num_movies, seq_len, hidden_dim]

# Calcola la somma pesata e il conteggio per ogni componente
weighted_sum_nonzero = (stacked_embeds * stacked_masks).sum(dim=0)  # [seq_len, hidden_dim]
count_nonzero = stacked_masks.sum(dim=0)  # [seq_len, hidden_dim]

# Evita divisione per zero
count_nonzero = torch.clamp(count_nonzero, min=1e-9)

# Media considerando solo componenti non-zero
mean_nonzero = weighted_sum_nonzero / count_nonzero
mean_nonzero_embeds = mean_nonzero.unsqueeze(0)  # [1, seq_len, hidden_dim]

# Per debug: mostra quante componenti sono state mediate per alcune posizioni

with torch.no_grad():
    output_nonzero = model.generate(
        inputs_embeds=mean_nonzero_embeds,
        max_new_tokens=300,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_nonzero = tokenizer.decode(output_nonzero[0], skip_special_tokens=True)
print(f"Output da media non-zero: {generated_text_nonzero}")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# === METODO 2a: Usando inputs_embeds direttamente ===
#
# --- Metodo 1: Media semplice degli embeddings ---
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# tensor([[[-4.3640e-03, -1.0633e-04, -5.6152e-03,  ..., -5.0545e-05,
#           -1.1520e-03,  1.5926e-04],
#          [-6.4850e-04,  6.1340e-03,  1.0757e-03,  ..., -8.8882e-04,
#           -3.4027e-03, -1.6403e-03],
#          [-9.8419e-04, -9.7275e-04,  4.5300e-05,  ..., -8.3923e-04,
#           -2.1100e-05, -1.4114e-03],
#          ...,
#          [-8.4639e-06,  2.2829e-05,  1.0073e-05,  ..., -1.6689e-06,
#            3.5286e-05,  3.9339e-06],
#          [-3.8743e-06, -8.5235e-06,  4.0531e-06,  ...,  2.8610e-06,
#           -7.5102e-06,  1.8895e-05],
#          [ 1.7881e-05,  1.2219e-05, -1.1742e-05,  ...,  3.5763e-06,
#           -3.8147e-06, -1.0371e-05]]], device='cuda:0', dtype=torch.float16,
#        grad_fn=<MeanBackward1>)
# Output da embeddings: {}�����€€™s
#
# --- Metodo 2: Media ponderata (peso basato su lunghezza) ---
# Output da media ponderata: {}����€€€€€
#
# --- Metodo 3: Media dei primi N token ---
# Output da media dei primi 100 token: rank: 11/30333
#
# # MERCHYNT'S MAGICAL CONTENT CALENDAR FOR MERCHYNT'S "MERCHYNT'S MAGICAL CONTENT CALENDAR FOR MERCHYNT'S "MERCHYNT'S MAGICAL CONTENT CALENDAR FOR MERCHYNT'S "MERCHYNT'S M
#
# --- Metodo 4: Media escludendo componenti zero (padding-aware) ---
# Output da media non-zero:
# Tags:
# ```
# "The Martian" is a science fiction novel by Andy Weir, published in 2011. The story follows Mark Watney, an astronaut stranded on Mars after a dust storm damages his habitat and communications equipment. Watney must use his ingenuity and scientific knowledge to survive on the planet until he can be rescued. The novel is a combination of science fiction and survival story, with a focus on the scientific methods and problem-solving skills of the protagonist. The novel has been praised for its realistic portrayal of science and engineering, as well as its engaging and humorous narrative. The novel has also been adapted into a successful film of the same name.
#
# The novel explores themes of survival, perseverance, and the human spirit. Watney's determination to survive and his resourcefulness in the face of seemingly insurmountable odds are central to the story. The novel also touches on the importance of community and the role of technology in modern society.
#
# The novel has been compared to the works of Jules Verne and Robert A. Heinlein, and has been praised for its accessibility to readers who may not be familiar with science fiction or technical subjects. The novel has also been praised for its humor and its ability to balance scientific detail with a compelling narrative.
#
# The novel has been described as a "hard science fiction" novel, meaning that it

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import warnings
warnings.filterwarnings('ignore')

# Carica modello e tokenizer
model_name = "mistralai/Mistral-7B-Instruct-v0.2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True
)
print("\n=== METODO 2a: Usando inputs_embeds direttamente ===")

# Metodo 1: Media semplice degli embeddings (ogni prompt contribuisce ugualmente)
print("\n--- Metodo 1: Media semplice degli embeddings ---")
input_embeds_list = []
max_length = 0

# Calcola embeddings per ogni movie
for i, movie in enumerate(movies):
    instuction = "You are a expert on movie. Based on the movie description, generate a short summary of the user taste."
    movie = f"{instuction}\n{movie}"
    inputs = tokenizer(movie, return_tensors="pt")
    input_ids = inputs["input_ids"].to(model.device)
    
    # Ottieni embeddings
    embeds = model.get_input_embeddings()(input_ids)
    input_embeds_list.append(embeds)
    
    max_length = max(max_length, embeds.shape[1])

# Pad tutti gli embeddings alla stessa lunghezza per poter fare la media
padded_embeds_list = []
mask_list = []
for embeds in input_embeds_list:
    if embeds.shape[1] < max_length:
        # Pad con zeros (o potresti usare il pad_token_id embedding)
        padding = torch.zeros(1, max_length - embeds.shape[1], embeds.shape[2], dtype=embeds.dtype).to(embeds.device)
        padded_embeds = torch.cat([embeds, padding], dim=1)
        # crea una maschera per i token non zero
        mask = torch.ones(1, embeds.shape[1],embeds.shape[2], dtype=torch.bool).to(embeds.device)
        mask = torch.cat([mask, torch.zeros(1, max_length - embeds.shape[1],embeds.shape[2], dtype=torch.bool).to(embeds.device)], dim=1)
    else:
        padded_embeds = embeds
        mask = torch.ones(1, embeds.shape[1],embeds.shape[2], dtype=torch.bool).to(embeds.device)
    padded_embeds_list.append(padded_embeds)
    mask_list.append(mask)

# Calcola la media
stacked_embeds = torch.stack([e.squeeze(0) for e in padded_embeds_list])  # [num_movies, seq_len, hidden_dim]
input_embeds = stacked_embeds.mean(dim=0, keepdim=True)  # [1, seq_len, hidden_dim]

print(input_embeds)  # Mostra i primi 5 embeddings
with torch.no_grad():
    # Genera usando inputs_embeds invece di input_ids
    output_from_embeds = model.generate(
        inputs_embeds=input_embeds,
        max_new_tokens=10,
        temperature=0.1,
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_embeds = tokenizer.decode(output_from_embeds[0], skip_special_tokens=True)
print(f"Output da embeddings: {generated_text_embeds}")

# Metodo 2: Media ponderata basata sulla lunghezza
print("\n--- Metodo 2: Media ponderata (peso basato su lunghezza) ---")
weighted_sum = torch.zeros_like(padded_embeds_list[0])
total_weight = 0

for embeds, original_embeds in zip(padded_embeds_list, input_embeds_list):
    weight = original_embeds.shape[1]  # Peso = lunghezza originale
    weighted_sum += embeds * weight
    total_weight += weight

weighted_mean_embeds = weighted_sum / total_weight

with torch.no_grad():
    output_weighted = model.generate(
        inputs_embeds=weighted_mean_embeds,
        max_new_tokens=10,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_weighted = tokenizer.decode(output_weighted[0], skip_special_tokens=True)
print(f"Output da media ponderata: {generated_text_weighted}")

# Metodo 3: Media solo dei primi N token di ogni prompt
print("\n--- Metodo 3: Media dei primi N token ---")
n_tokens = 100  # Prendi solo i primi 5 token di ogni prompt

truncated_embeds_list = []
for i, movie in enumerate(movies):
    instuction = "You are a expert on movie. Based on the movie description, generate a short summary of the user taste."
    movie = f"{instuction}\n{movie}"
    inputs = tokenizer(movie, return_tensors="pt", max_length=n_tokens, truncation=True)
    input_ids = inputs["input_ids"].to(model.device)
    embeds = model.get_input_embeddings()(input_ids)
    
    # Assicurati che abbiano tutti esattamente n_tokens
    if embeds.shape[1] < n_tokens:
        padding = torch.zeros(1, n_tokens - embeds.shape[1], embeds.shape[2], dtype=embeds.dtype).to(embeds.device)
        embeds = torch.cat([embeds, padding], dim=1)
    
    truncated_embeds_list.append(embeds)

# Stack e media
stacked_truncated = torch.stack([e.squeeze(0) for e in truncated_embeds_list])
mean_truncated = stacked_truncated.mean(dim=0, keepdim=True)

with torch.no_grad():
    output_truncated = model.generate(
        inputs_embeds=mean_truncated,
        max_new_tokens=100,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_truncated = tokenizer.decode(output_truncated[0], skip_special_tokens=True)
print(f"Output da media dei primi {n_tokens} token: {generated_text_truncated}")

print("\n--- Metodo 4: Media escludendo componenti zero (padding-aware) ---")

# Crea maschere per identificare le posizioni con padding (tutti zeri)
masks_list = []
for embeds, original_embeds in zip(padded_embeds_list, input_embeds_list):
    # Crea una maschera: 1 per posizioni valide, 0 per padding
    mask = torch.ones_like(embeds)
    if embeds.shape[1] > original_embeds.shape[1]:
        # Le posizioni dopo la lunghezza originale sono padding
        mask[:, original_embeds.shape[1]:, :] = 0
    masks_list.append(mask)

# Stack embeddings e maschere
stacked_embeds = torch.stack([e.squeeze(0) for e in padded_embeds_list])  # [num_movies, seq_len, hidden_dim]
stacked_masks = torch.stack([m.squeeze(0) for m in masks_list])  # [num_movies, seq_len, hidden_dim]

# Calcola la somma pesata e il conteggio per ogni componente
weighted_sum_nonzero = (stacked_embeds * stacked_masks).sum(dim=0)  # [seq_len, hidden_dim]
count_nonzero = stacked_masks.sum(dim=0)  # [seq_len, hidden_dim]

# Evita divisione per zero
count_nonzero = torch.clamp(count_nonzero, min=1e-9)

# Media considerando solo componenti non-zero
mean_nonzero = weighted_sum_nonzero / count_nonzero
mean_nonzero_embeds = mean_nonzero.unsqueeze(0)  # [1, seq_len, hidden_dim]

# Per debug: mostra quante componenti sono state mediate per alcune posizioni

with torch.no_grad():
    output_nonzero = model.generate(
        inputs_embeds=mean_nonzero_embeds,
        max_new_tokens=300,
        temperature=0.1,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_nonzero = tokenizer.decode(output_nonzero[0], skip_special_tokens=True)
print(f"Output da media non-zero: {generated_text_nonzero}")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# === METODO 2a: Usando inputs_embeds direttamente ===
#
# --- Metodo 1: Media semplice degli embeddings ---
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# tensor([[[-4.3640e-03, -1.0633e-04, -5.6152e-03,  ..., -5.0545e-05,
#           -1.1520e-03,  1.5926e-04],
#          [ 1.0529e-03, -8.8882e-04,  2.1515e-03,  ..., -4.1504e-03,
#            1.5640e-03, -1.4420e-03],
#          [ 1.9932e-04,  3.2806e-04, -2.8687e-03,  ..., -9.0790e-04,
#           -8.3160e-04, -1.4038e-03],
#          ...,
#          [-8.4639e-06,  2.2829e-05,  1.0073e-05,  ..., -1.6689e-06,
#            3.5286e-05,  3.9339e-06],
#          [-3.8743e-06, -8.5235e-06,  4.0531e-06,  ...,  2.8610e-06,
#           -7.5102e-06,  1.8895e-05],
#          [ 1.7881e-05,  1.2219e-05, -1.1742e-05,  ...,  3.5763e-06,
#           -3.8147e-06, -1.0371e-05]]], device='cuda:0', dtype=torch.float16,
#        grad_fn=<MeanBackward1>)
# Output da embeddings: {}
#
#
#
#
#
#
#
# --- Metodo 2: Media ponderata (peso basato su lunghezza) ---
# Output da media ponderata: {}
#
#
#
#
#
# --- Metodo 3: Media dei primi N token ---
# Output da media dei primi 100 token: jar jar binks
#
# Based on the title and description, it appears that this movie is a Star Wars spin-off featuring the character Jar Jar Binks. Given that Jar Jar Binks is a divisive character among Star Wars fans, it's difficult to summarize user taste accurately without more context. However, we can make some assumptions based on previous reactions to Jar Jar Binks in the Star Wars franchise.
#
# Some fans may be excited for a movie focused on this character, as they enjoy his unique personality and contributions to the Star Wars universe. Others, however, may be less enthusiastic or even dislike the idea of a Jar Jar Binks-centric movie, as they find the character annoying or grating.
#
# It's also worth noting that the title and description don't provide any information about the plot or tone of the movie, so user taste could vary widely depending on those factors as well. Overall, it's safe to say that opinions on a Jar Jar Binks movie will be divided among Star Wars fans.
#
# --- Metodo 4: Media escludendo componenti zero (padding-aware) ---
# Output da media non-zero:
# User Taste: This user enjoys movies that combine elements of action, adventure, romance, and thriller genres. They appreciate stories that involve survival against the odds, reuniting with loved ones, and second chances in life and relationships. Movies with strong character development, engaging plot twists, and emotional depth resonate with them. They may also enjoy movies that explore scientific or technological themes, as seen in the description of "The Meg."

# %%
from collections import Counter
all_genres = []
for movie_string in movies:
    lines = movie_string.strip().split('\n')
    genre_line = lines[-1]
    genres_text = genre_line.replace('Genre: ', '')
    all_genres.extend(genres_text.split('|'))

genre_counts = Counter(all_genres)
top_10_genres = genre_counts.most_common(10)

print("I 10 generi più frequenti sono:")
for i, (genre, count) in enumerate(top_10_genres):
    print(f"{i+1}. {genre}: {count} occorrenze")
# Out:
# I 10 generi più frequenti sono:
# 1. Adventure: 70 occorrenze
# 2. Comedy: 66 occorrenze
# 3. Action: 63 occorrenze
# 4. Drama: 50 occorrenze
# 5. Thriller: 48 occorrenze
# 6. Fantasy: 39 occorrenze
# 7. Crime: 35 occorrenze
# 8. Sci-Fi: 33 occorrenze
# 9. Children: 32 occorrenze
# 10. Animation: 21 occorrenze

# %%
# Carica modello e tokenizer
model_name = "mistralai/Mistral-7B-Instruct-v0.2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True
)

# Input di esempio
input_text = movies[1]
print("=== METODO 1: Generazione normale dal testo ===")
# Tokenizza l'input
inputs = tokenizer(input_text, return_tensors="pt")
input_ids = inputs["input_ids"].to(model.device)
input_length = input_ids.shape[1]

# Genera testo normalmente
with torch.no_grad():
    output_normal = model.generate(
        input_ids,
        max_new_tokens=50,
        temperature=0.1,  # Bassa temperatura per risultati deterministici
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )
# Decodifica solo i nuovi token generati (escludendo l'input)
generated_tokens = output_normal[0][input_length:]
generated_text_normal = tokenizer.decode(generated_tokens, skip_special_tokens=True)
print(f"Input: {input_text}")
print(f"Output: {generated_text_normal}\n")

print("=== METODO 2: Generazione dagli hidden states ===")

# Ottieni gli hidden states dell'input
with torch.no_grad():
    # Forward pass per ottenere gli hidden states
    outputs = model(
        input_ids=input_ids,
        output_hidden_states=True,
        return_dict=True
    )
    
    # Prendi l'ultimo hidden state (output dell'ultimo layer)
    last_hidden_state = outputs.hidden_states[-1]
    
    print(f"Forma hidden states: {last_hidden_state.shape}")
    print(f"Numero di layer: {len(outputs.hidden_states)}")

# Metodo alternativo: usa direttamente inputs_embeds
print("\n=== METODO 2a: Usando inputs_embeds direttamente ===")

# Ottieni gli embeddings dell'input
input_embeds = model.get_input_embeddings()(input_ids)
print (f"Forma input embeddings: {input_embeds.shape}")
print(input_embeds)  # Mostra i primi 5 embeddings
with torch.no_grad():
    # Genera usando inputs_embeds invece di input_ids
    output_from_embeds = model.generate(
        inputs_embeds=input_embeds,
        max_new_tokens=50,
        temperature=0.1,
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_embeds = tokenizer.decode(output_from_embeds[0], skip_special_tokens=True)
print(f"Output da embeddings: {generated_text_embeds}")

# Verifica che siano uguali
print("\n=== CONFRONTO RISULTATI ===")
print(f"Testo normale: {generated_text_normal}")
print(f"Testo da embeddings: {generated_text_embeds}")
print(f"I risultati sono identici: {generated_text_normal == generated_text_embeds}")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# === METODO 1: Generazione normale dal testo ===
# Input: Title: Dark Knight Rises, The
# Description: Following the death of District Attorney Harvey Dent, Batman assumes responsibility for Dent's crimes to protect the late attorney's reputation and is subsequently hunted by the Gotham City Police Department. Eight years later, Batman encounters the mysterious Selina Kyle and the villainous Bane, a new terrorist leader who overwhelms Gotham's finest. The Dark Knight resurfaces to protect a city that has branded him an enemy.
# Genre: Action|Adventure|Crime|IMAX
# Output: |Thriller
# Release Date: 2012-07-20
# Runtime: 165 minutes
# Director: Christopher Nolan
# Writer: Jonathan Nolan, Christopher Nolan, David S. Goy
#
# === METODO 2: Generazione dagli hidden states ===
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Forma hidden states: torch.Size([1, 121, 4096])
# Numero di layer: 33
#
# === METODO 2a: Usando inputs_embeds direttamente ===
# Forma input embeddings: torch.Size([1, 121, 4096])
# tensor([[[-4.3640e-03, -1.0633e-04, -5.6152e-03,  ..., -5.0545e-05,
#           -1.1520e-03,  1.5926e-04],
#          [-6.4850e-04,  6.1340e-03,  1.0757e-03,  ..., -8.8882e-04,
#           -3.4027e-03, -1.6403e-03],
#          [-9.8419e-04, -9.7275e-04,  4.5300e-05,  ..., -8.3923e-04,
#           -2.1100e-05, -1.4114e-03],
#          ...,
#          [-2.4319e-04, -1.5717e-03,  8.4686e-04,  ...,  9.1171e-04,
#            1.1368e-03,  8.2397e-04],
#          [ 1.0452e-03, -8.1635e-04, -1.4954e-03,  ...,  1.0147e-03,
#           -4.6921e-04, -1.3199e-03],
#          [-1.9684e-03,  1.2512e-03,  9.4986e-04,  ..., -3.0365e-03,
#            1.8616e-03, -5.0354e-03]]], device='cuda:0', dtype=torch.float16,
#        grad_fn=<EmbeddingBackward0>)
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Output da embeddings: |Thriller
# Release Date: 2012-07-20
# Runtime: 165 minutes
# Director: Christopher Nolan
# Writer: Jonathan Nolan, Christopher Nolan, David S. Goy
#
# === CONFRONTO RISULTATI ===
# Testo normale: |Thriller
# Release Date: 2012-07-20
# Runtime: 165 minutes
# Director: Christopher Nolan
# Writer: Jonathan Nolan, Christopher Nolan, David S. Goy
# Testo da embeddings: |Thriller
# Release Date: 2012-07-20
# Runtime: 165 minutes
# Director: Christopher Nolan
# Writer: Jonathan Nolan, Christopher Nolan, David S. Goy
# I risultati sono identici: True
#
# === BONUS: Uso di hidden states da layer intermedio ===
#
# Forma hidden state layer 16: torch.Size([1, 121, 4096])
# Gli hidden states intermedi richiederebbero un wrapper personalizzato per la generazione.
#
# === SALVATAGGIO HIDDEN STATES ===
# Hidden states pronti per il salvataggio (decommentare la riga sopra per salvare)
#
# === RIUTILIZZO HIDDEN STATES ===
# Output da embeddings ricaricati: |Thriller
# Release Date: 2012-07-20
# Runtime: 165 minutes
# Director: Christopher Nolan
# Writer: Jonathan Nolan, Christopher Nolan, David S. Goy

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import warnings
warnings.filterwarnings('ignore')

# Carica modello e tokenizer
model_name = "mistralai/Mistral-7B-Instruct-v0.2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True
)

# Input di esempio
input_text = "what is the stronger football player?"
print("=== METODO 1: Generazione normale dal testo ===")
# Tokenizza l'input
inputs = tokenizer(input_text, return_tensors="pt")
input_ids = inputs["input_ids"].to(model.device)
input_length = input_ids.shape[1]

# Genera testo normalmente
with torch.no_grad():
    output_normal = model.generate(
        input_ids,
        max_new_tokens=50,
        temperature=0.1,  # Bassa temperatura per risultati deterministici
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )
# Decodifica solo i nuovi token generati (escludendo l'input)
generated_tokens = output_normal[0][input_length:]
generated_text_normal = tokenizer.decode(generated_tokens, skip_special_tokens=True)
print(f"Input: {input_text}")
print(f"Output: {generated_text_normal}\n")

print("=== METODO 2: Generazione dagli hidden states ===")

# Ottieni gli hidden states dell'input
with torch.no_grad():
    # Forward pass per ottenere gli hidden states
    outputs = model(
        input_ids=input_ids,
        output_hidden_states=True,
        return_dict=True
    )
    
    # Prendi l'ultimo hidden state (output dell'ultimo layer)
    last_hidden_state = outputs.hidden_states[-1]
    
    print(f"Forma hidden states: {last_hidden_state.shape}")
    print(f"Numero di layer: {len(outputs.hidden_states)}")

# Metodo alternativo: usa direttamente inputs_embeds
print("\n=== METODO 2a: Usando inputs_embeds direttamente ===")

# Metodo 1: Media semplice degli embeddings (ogni prompt contribuisce ugualmente)
print("\n--- Metodo 1: Media semplice degli embeddings ---")
input_embeds_list = []
max_length = 0

# Calcola embeddings per ogni movie
eletto = movies[1]  # Scegli un movie specifico per il test

for i, movie in enumerate(movies):
    inputs = tokenizer(eletto, return_tensors="pt")
    input_ids = inputs["input_ids"].to(model.device)
    
    # Ottieni embeddings
    embeds = model.get_input_embeddings()(input_ids)
    input_embeds_list.append(embeds)
    
    max_length = max(max_length, embeds.shape[1])
    print(f"Movie {i}: '{eletto[:30]}...' - Forma embeddings: {embeds.shape}")

# Pad tutti gli embeddings alla stessa lunghezza per poter fare la media
padded_embeds_list = []
for embeds in input_embeds_list:
    if embeds.shape[1] < max_length:
        # Pad con zeros (o potresti usare il pad_token_id embedding)
        padding = torch.zeros(1, max_length - embeds.shape[1], embeds.shape[2], dtype=embeds.dtype).to(embeds.device)
        padded_embeds = torch.cat([embeds, padding], dim=1)
    else:
        padded_embeds = embeds
    padded_embeds_list.append(padded_embeds)

# Calcola la media
stacked_embeds = torch.stack([e.squeeze(0) for e in padded_embeds_list])  # [num_movies, seq_len, hidden_dim]
input_embeds = stacked_embeds.mean(dim=0, keepdim=True)  # [1, seq_len, hidden_dim]

print(f"\nForma embeddings dopo padding: {stacked_embeds.shape}")
print(f"Forma media embeddings: {input_embeds.shape}")


print (f"Forma input embeddings: {input_embeds.shape}")
print(input_embeds)  # Mostra i primi 5 embeddings
with torch.no_grad():
    # Genera usando inputs_embeds invece di input_ids
    output_from_embeds = model.generate(
        inputs_embeds=input_embeds,
        max_new_tokens=50,
        temperature=0.1,
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )

generated_text_embeds = tokenizer.decode(output_from_embeds[0], skip_special_tokens=True)
print(f"Output da embeddings: {generated_text_embeds}")

# Verifica che siano uguali
print("\n=== CONFRONTO RISULTATI ===")
print(f"Testo normale: {generated_text_normal}")
print(f"Testo da embeddings: {generated_text_embeds}")
print(f"I risultati sono identici: {generated_text_normal == generated_text_embeds}")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# === METODO 1: Generazione normale dal testo ===
# Input: what is the stronger football player?
# Output:
#
# The term "stronger football player" can be interpreted in different ways, depending on the context. Here are a few possible interpretations and some factors that could influence the answer:
#
# 1. Physical strength: In terms of raw muscle
#
# === METODO 2: Generazione dagli hidden states ===
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Forma hidden states: torch.Size([1, 8, 4096])
# Numero di layer: 33
#
# === METODO 2a: Usando inputs_embeds direttamente ===
#
# --- Metodo 1: Media semplice degli embeddings ---
# Movie 0: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 1: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 2: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 3: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 4: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 5: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 6: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 7: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 8: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 9: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 10: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 11: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 12: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 13: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 14: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 15: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 16: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 17: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 18: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 19: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 20: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 21: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 22: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 23: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 24: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
# Movie 25: 'Title: Dark Knight Rises, The
# ...' - Forma embeddings: torch.Size([1, 121, 4096])
#
# Forma embeddings dopo padding: torch.Size([26, 121, 4096])
# Forma media embeddings: torch.Size([1, 121, 4096])
# Forma input embeddings: torch.Size([1, 121, 4096])
# tensor([[[-4.3640e-03, -1.0633e-04, -5.6152e-03,  ..., -5.0545e-05,
#           -1.1520e-03,  1.5926e-04],
#          [-6.4850e-04,  6.1340e-03,  1.0757e-03,  ..., -8.8882e-04,
#           -3.4027e-03, -1.6403e-03],
#          [-9.8419e-04, -9.7275e-04,  4.5300e-05,  ..., -8.3923e-04,
#           -2.1100e-05, -1.4114e-03],
#          ...,
#          [-2.4319e-04, -1.5717e-03,  8.4686e-04,  ...,  9.1171e-04,
#            1.1368e-03,  8.2397e-04],
#          [ 1.0452e-03, -8.1635e-04, -1.4954e-03,  ...,  1.0147e-03,
#           -4.6921e-04, -1.3199e-03],
#          [-1.9684e-03,  1.2512e-03,  9.4986e-04,  ..., -3.0365e-03,
#            1.8616e-03, -5.0354e-03]]], dtype=torch.float16,
#        grad_fn=<MeanBackward1>)
# Output da embeddings: |Thriller
# Release Date: 2012-07-20
# Runtime: 165 minutes
# Director: Christopher Nolan
# Writer: Jonathan Nolan, Christopher Nolan, David S. Goy
#
# === CONFRONTO RISULTATI ===
# Testo normale:
#
# The term "stronger football player" can be interpreted in different ways, depending on the context. Here are a few possible interpretations and some factors that could influence the answer:
#
# 1. Physical strength: In terms of raw muscle
# Testo da embeddings: |Thriller
# Release Date: 2012-07-20
# Runtime: 165 minutes
# Director: Christopher Nolan
# Writer: Jonathan Nolan, Christopher Nolan, David S. Goy
# I risultati sono identici: False
